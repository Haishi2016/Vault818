# %%
import tensorflow as tf
import numpy as np

# %%
X = np.array([[0],[1],[2]])  # 0 - Rock; 1 - Paper; 2 - Scissors
y = np.array([1,2,0])

# %%
X_train = tf.keras.utils.normalize(X, axis=0)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(30, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(30, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(3, activation=tf.nn.softmax))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y, epochs = 200)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 0s 2ms/sample - loss: 0.5712 - acc: 0.6667
# Epoch 2/200
# 3/3 [==============================] - 0s 666us/sample - loss: 0.5688 - acc: 0.6667
# Epoch 3/200
# 3/3 [==============================] - 0s 667us/sample - loss: 0.5663 - acc: 0.6667
# Epoch 4/200
# 3/3 [==============================] - 0s 667us/sample - loss: 0.5639 - acc: 0.6667
# Epoch 5/200
# 3/3 [==============================] - 0s 667us/sample - loss: 0.5614 - acc: 0.6667
# Epoch 6/200
# 3/3 [==============================] - 0s 666us/sample - loss: 0.5590 - acc: 0.6667
# Epoch 7/200
# 3/3 [==============================] - 0s 333us/sample - loss: 0.5566 - acc: 0.6667
# Epoch 8/200
# 3/3 [==============================] - 0s 4ms/sample - loss: 0.5541 - acc: 0.6667
# Epoch 9/200
# 3/3 [==============================] - 0s 1000us/sample - loss: 0.5516 - acc: 0.6667
# Epoch 10/200
# 3/3 [==============================] - 0s 333us/sample - loss: 0.5493 - acc: 0.6667
# ...

# %%
val_loss, val_acc = model.evaluate(X_train, y)
# Out:
# 3/3 [==============================] - 0s 15ms/sample - loss: 0.1401 - acc: 1.0000

# %%
prediction = model.predict([X_train])

# %%
throws = np.array(["rock", "paper","scissors"])

# %%
for i in range(X.shape[0]):
    print(throws[np.argmax(prediction[i])], "beats", throws[X[i][0]])
# Out:
# paper beats rock
# scissors beats paper
# rock beats scissors
